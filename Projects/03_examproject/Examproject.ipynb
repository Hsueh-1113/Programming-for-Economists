# %% [markdown]
# # Exam Project

# %% [markdown]
# Import and set magics:

# %%
import pandas as pd
import numpy as np
import requests

import matplotlib.pyplot as plt
import matplotlib.dates as mdates


from io import StringIO
from dstapi import DstApi
from ExchangeEconomyModel import ExchangeEconomyModelClass
from ASADModel import ASADModelClass
import importlib

# user written modules
import question1_1 as q1_1
import question1_2 as q1_2
import question1_3 as q1_3
import question1_4 as q1_4

import question2_1 as q2_1
import question2_2 as q2_2
import question2_3 as q2_3
import question2_4 as q2_4
import question2_5 as q2_5

import question3_1 as q3_1
import question3_2 as q3_2
import question3_3 as q3_3

# autoreload modules when code is run
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Part 1 - Danish House Prices

# %% [markdown]
# ### Question 1.1

# %%
importlib.reload(q1_1)
# Out:
# Table EJ56: Price index for sales of property by region, category of real property, unit and time
# Last update: 2026-01-08T08:00:00
# Ranking of provinces by total house price growth:
# province
# Province Byen København          806.400000
# Province Københavns omegn        623.376623
# Province Nordsjælland            481.052632
# Province Østsjælland             431.707317
# Province Østjylland              339.917695
# Province Fyn                     289.130435
# Province Vest- og Sydsjælland    246.774194
# Province Sydjylland              208.211144
# Province Nordjylland             198.525074
# Province Vestjylland             154.500000
# Name: 2025-07-01 00:00:00, dtype: float64
# <module 'question1_1' from '/Users/lishixue/Documents/2025 winter/Programming for Economists/projects-2025-ultrasonic-3/03_examproject/question1_1.py'>

# %% [markdown]
# ### Question 1.2

# %%
importlib.reload(q1_2)
# Out:
# Table PRIS113: Consumer price index by type and time
# Last update: 2026-01-12T08:00:00
# <module 'question1_2' from '/Users/lishixue/Documents/2025 winter/Programming for Economists/projects-2025-ultrasonic-3/03_examproject/question1_2.py'>

# %% [markdown]
# ### Question 1.3

# %%
importlib.reload(q1_3)
# Out:
# drop_cols = ['Unnamed: 0', 'Unnamed: 1']
# Correlation: 0.897341554465683
# <module 'question1_3' from '/Users/lishixue/Documents/2025 winter/Programming for Economists/projects-2025-ultrasonic-3/03_examproject/question1_3.py'>

# %% [markdown]
# There is a clear positive relationship between the initial price level and total house price growth.
#
# High-price municipalities such as Gentofte, København, Lyngby-Taarbæk, Rudersdal, and Hørsholm display both high initial prices and high total growth. In contrast, municipalities with lower initial price levels cluster in the bottom-left of the figure and show substantially smaller increases in house prices.
#
# Overall, the results suggest that regional house price inequality has increased over time, as municipalities that were initially more expensive experienced faster price growth than cheaper municipalities.

# %% [markdown]
# ### Question 1.4

# %%
importlib.reload(q1_4)
# Out:
# <module 'question1_4' from '/Users/lishixue/Documents/2025 winter/Programming for Economists/projects-2025-ultrasonic-3/03_examproject/question1_4.py'>

# %% [markdown]
# The majority of municipalities exhibit positive changes, indicating that current rolling-average house prices are higher than before the financial crisis.
#
# Urban and high-demand municipalities experienced large post-crisis price increases and clearly surpassed their historical peaks, like Frederiksberg, København, Gentofte, and Lyngby-Taarbæk.
#
# Several rural and peripheral municipalities continue to lag behind, with house prices still below their pre-crisis peak even after more than a decade.These municipalities have not yet fully recovered their four-quarter rolling-average house price levels observed prior to the 2008 Financial Crisis for example : Vordingborg,Stevns,Halsnæs,Odsherred and Lolland.
#
# Overall, the analysis indicates that while the Danish housing market as a whole has recovered from the 2008 Financial Crisis, the recovery has been uneven across municipalities.

# %% [markdown]
# ## 2 Exchange economy

# %% [markdown]
# ### 2.1 Question 1

# %%
importlib.reload(q2_1)
# Out:
# Sign-change intervals [pL, pR]:
# [0.3939393939393939, 0.44191919191919193]
# [0.9696969696969696, 1.0176767676767677]
# [2.361111111111111, 2.4090909090909087]
# There are 3 equilibria.
# <module 'question2_1' from '/Users/lishixue/Documents/2025 winter/Programming for Economists/projects-2025-ultrasonic-3/03_examproject/question2_1.py'>

# %% [markdown]
# ### 2.2 Question 2

# %%
importlib.reload(q2_2)
# Out:
# method=tatonnement, p1*=0.42187628, iterations=33, eps1=-8.179e-09
# method=tatonnement, p1*=2.37035615, iterations=291, eps1=9.569e-09
# <module 'question2_2' from '/Users/lishixue/Documents/2025 winter/Programming for Economists/projects-2025-ultrasonic-3/03_examproject/question2_2.py'>

# %% [markdown]
# Yes. the plots show **path dependence**:
#
# - Starting from **$p_1^0 = 0.9$**, the tâtonnement updates push prices down and it **converges to the low-price equilibrium** (around **$p_1 \approx 0.4$**), with **$\epsilon_1^k \to 0$** from below.
#
# - Starting from **$p_1^0 = 1.1$**, prices are pushed up and it **converges to the high-price equilibrium** (around **$p_1 \approx 2.36$**), with **$\epsilon_1^k \to 0$** from above.

# %% [markdown]
# ### 2.3 Question 3

# %%
importlib.reload(q2_3)
# Out:
# Distinct p1* (approx): [0.4218762011667069, 2.3703561417615266]
# <module 'question2_3' from '/Users/lishixue/Documents/2025 winter/Programming for Economists/projects-2025-ultrasonic-3/03_examproject/question2_3.py'>

# %% [markdown]
# No. With tâtonnement over $p_1^0 \in [0.25,5]$, the algorithm converges to **two** stable equilibria (around $p_1^* \approx 0.422$ and $p_1^* \approx 2.370$). The **middle equilibrium** (near $p_1 \approx 1$) is **unstable**, so it is typically not found unless the initial guess is extremely close to it.

# %% [markdown]
# ### 2.4 Question 4

# %%
importlib.reload(q2_4)
# Out:
# Distinct p1* (approx): [0.42187470891190787, 0.999994516944577, 2.370355937457412]
# <module 'question2_4' from '/Users/lishixue/Documents/2025 winter/Programming for Economists/projects-2025-ultrasonic-3/03_examproject/question2_4.py'>

# %% [markdown]
# Yes. With dampened Newton–Raphson, the algorithm converges to **all three equilibria** (approximately $p_1^* \approx 0.42$, $p_1^* \approx 1.00$, and $p_1^* \approx 2.37$) for different initial guesses in $p_1^0 \in [0.25,5]$.

# %% [markdown]
# ### 2.5 Question 5

# %%
importlib.reload(q2_5)
# Out:
# Equilibria p1* found: [0.42187470891190787, 0.9999941468266719, 2.3703556567172557]
# <module 'question2_5' from '/Users/lishixue/Documents/2025 winter/Programming for Economists/projects-2025-ultrasonic-3/03_examproject/question2_5.py'>

# %% [markdown]
# The three equilibrium prices
# $p_1*$≈0.422,1.000 and 2.370
#
# At each equilibrium allocation, the indifference curves of the two consumers are tangent, confirming Pareto efficiency. Markets clear and both consumers maximize utility given prices.While all equilibria are Pareto efficient, they differ substantially in the distribution of goods between consumers

# %% [markdown]
# ## 3 The AS-AD Model

# %% [markdown]
# ### 3.1 Question 1

# %%
importlib.reload(q3_1)
# Out:
# Long-run eq: y=1.000000, pi=0.020000
# New eq (pi_e=0.08, v=0): y*=0.988412, pi*=0.033648
# <module 'question3_1' from '/Users/lishixue/Documents/2025 winter/Programming for Economists/projects-2025-ultrasonic-3/03_examproject/question3_1.py'>

# %% [markdown]
# ### 3.2 Question 2

# %%
importlib.reload(q3_2)
# Out:
# <module 'question3_2' from '/Users/lishixue/Documents/2025 winter/Programming for Economists/projects-2025-ultrasonic-3/03_examproject/question3_2.py'>

# %% [markdown]
# ### 3.3 Question 3

# %%
importlib.reload(q3_3)
# Out:
# rho = 0.80
# sd(y*)  = 0.002701
# sd(pi*) = 0.016808
# corr(y*, pi*) = 0.514254
# ----------------------------------------
# rho = 0.50
# sd(y*)  = 0.002394
# sd(pi*) = 0.010929
# corr(y*, pi*) = 0.700982
# ----------------------------------------
# <module 'question3_3' from '/Users/lishixue/Documents/2025 winter/Programming for Economists/projects-2025-ultrasonic-3/03_examproject/question3_3.py'>
